# %%
import matplotlib
from matplotlib import pyplot as plt
import numpy
import math
import random

# %%
functions = [lambda x : x, 
             lambda x : 101 - x,
             lambda x : 50.5 + 49.5 * math.sin(math.pi / 2 + x / (5 * math.pi)),
             lambda x : random.randint(1, 101)]

# %%
points = []
xs = []
ys = []
for i in range(50):
    x = random.randint(1,101)
    y = functions[2](x)
#     print(x, y)
    points.append((x,y))
    xs.append(x)
    ys.append(y)

# %%
plt.figure()
plt.scatter(xs, ys, color="green")

# %%
def plot_function(func_num, plot=True):
    points = []
    xs = []
    ys = []
    colors = ['maroon', 'blue', 'green', 'orange']
    for i in range(50):
        x = random.randint(1,101)
        y = functions[func_num](x)
    #     print(x, y)
        points.append((x,y))
        xs.append(x)
        ys.append(y)
    if plot:
        plt.figure()
        plt.scatter(xs, ys, color=colors[func_num])
    return (xs, ys)

# %%
for i in range(4):
    plot_function(i)

# %%
# generate graph for first function
xs, ys = plot_function(1, plot=False)

# take first 25 without replacement
bag_x = []
bag_y = []
for i in range(25):
    ind = random.randint(0, len(xs)-1)
    x = xs.pop(ind)
    y = ys.pop(ind)
#     print(x,y)
# Out:
# 31 70
# 78 23
# 18 83
# 68 33
# 71 30
# 3 98
# 49 52
# 71 30
# 83 18
# 94 7
# 24 77
# 7 94
# 5 96
# 33 68
# 39 62
# 16 85
# 13 88
# 97 4
# 59 42
# 6 95
# 94 7
# 3 98
# 49 52
# 38 63
# 27 74
