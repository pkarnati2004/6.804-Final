# %%
import matplotlib
from matplotlib import pyplot as plt
import math
import random

import pymc3 as pm
import theano.tensor as tt
import theano

import numpy as np
from scipy import stats

# %% [markdown]
# # Plot functions

# %%
functions = [lambda x : x, 
             lambda x : 100 - x,
             lambda x : 50.5 + 49.5 * math.sin(math.pi / 2 + x / (5 * math.pi)),
             lambda x : random.randint(1, 101)]

# %%
def plot_function(func_num, plot=True, num_points=50):
    """
    Plot 50 (x,y) pairs for given function
    """
    points = []
    xs = []
    ys = []
    colors = ['maroon', 'blue', 'green', 'orange']
    for i in range(num_points):
        x = random.randint(1,101)
        y = functions[func_num](x)
    #     print(x, y)
        points.append((x,y))
        xs.append(x)
        ys.append(y)
    if plot:
        plt.figure()
        plt.scatter(xs, ys, color=colors[func_num])
    return (xs, ys)

# %%
xs_1, ys_1 = plot_function(1, plot=True, num_points=50)
xs = list(np.copy(xs_1))
ys = list(np.copy(ys_1))

# %%
train_x = []
train_y = []
for i in range(25):
    ind = random.randint(0, len(xs)-1)
    x = xs.pop(ind)
    y = ys.pop(ind)
    
    train_x.append(x)
    train_y.append(y)
plt.scatter(train_x, train_y)

# %%
len(train_x), len(train_y), len(xs), len(ys)
# Out:
# (25, 25, 25, 25)

# %%
neg_traces = []

# %%
N= 25
X = train_x
Y = train_y

X_test = xs


# learning 

with pm.Model() as model:
    siga = 1
    sigb = 10
    
    print('Creating model...')
    
    a1 = pm.Normal('a1', mu=1, sigma=siga)
    b1 = pm.Normal('b1', mu=0, sigma=sigb)
    a2 = pm.Normal('a2', mu=-1, sigma=siga)
    b2 = pm.Normal('b2', mu=100, sigma=sigb)

    a = pm.Deterministic('a', tt.stack([a1, a2]))
    b = pm.Deterministic('b', tt.stack([b1, b2]))


    # Dirichlet distribution returns an array of probabilties
    # returns the prior distribution on the categorical distribution
    # alpha = (4,1) states that the categorical distribution is initially
    #         more heavily weighted towards the first value in the categorical
    #         array which is the positive slope
    p = pm.Dirichlet('p', a=np.array([4,1]))

    print('Training on 50 points...')
    
    for i in range(N):
        z = pm.Categorical('z_%u' % i, p=p)
        mu = a[z]*X[i] + b[z]
        y = pm.Normal('y_%u' % i, mu=mu, sigma=2, observed=Y[i])
        
    print('Generating test set...')
    
    for i in range(N):
        z_test = pm.Categorical('z_test_%u' % i, p=p)
        mu_test = a[z_test]*X_test[i] + b[z_test]
        y_test = pm.Normal('y_test_%u' % i, mu=mu_test, sigma=2)
    
    trace = pm.sample(100)
    neg_traces.append(trace)
        
print('Generating graph for next generation...')
Y_test = []
for i in range(N):
    y_pos = trace['y_test_%u'%i]
    Y_test.append(np.random.choice(y_pos))
plt.figure()
# Out:
# Creating model...
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# Training on 50 points...
# Generating test set...
# Only 100 samples in chain.
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [y_test_24, y_test_23, y_test_22, y_test_21, y_test_20, y_test_19, y_test_18, y_test_17, y_test_16, y_test_15, y_test_14, y_test_13, y_test_12, y_test_11, y_test_10, y_test_9, y_test_8, y_test_7, y_test_6, y_test_5, y_test_4, y_test_3, y_test_2, y_test_1, y_test_0, p, b2, a2, b1, a1]
# >BinaryGibbsMetropolis: [z_0, z_1, z_2, z_3, z_4, z_5, z_6, z_7, z_8, z_9, z_10, z_11, z_12, z_13, z_14, z_15, z_16, z_17, z_18, z_19, z_20, z_21, z_22, z_23, z_24, z_test_0, z_test_1, z_test_2, z_test_3, z_test_4, z_test_5, z_test_6, z_test_7, z_test_8, z_test_9, z_test_10, z_test_11, z_test_12, z_test_13, z_test_14, z_test_15, z_test_16, z_test_17, z_test_18, z_test_19, z_test_20, z_test_21, z_test_22, z_test_23, z_test_24]
# Sampling 4 chains, 2 divergences: 100%|██████████| 2400/2400 [03:05<00:00, 12.95draws/s]
# /Users/pkarnati/Library/Python/3.6/lib/python/site-packages/xarray/core/nputils.py:223: RuntimeWarning: All-NaN slice encountered
#   result = getattr(npmodule, name)(values, axis=axis, **kwargs)
# The chain reached the maximum tree depth. Increase max_treedepth, increase target_accept or reparameterize.
# The acceptance probability does not match the target. It is 0.9252259248055686, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# The chain reached the maximum tree depth. Increase max_treedepth, increase target_accept or reparameterize.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The number of effective samples is smaller than 10% for some parameters.
# Generating graph for next generation...

# %%
Y_test = []
for i in range(N):
    y_pos = trace['y_test_%u'%i]
    Y_test.append(np.random.choice(y_pos))
plt.figure()
plt.scatter(X_test, Y_test, color="#FF00FF")
plt.ylim([0,100])
plt.xlim([0,100])
# plt.savefig('neg_gen_%i.jpeg'%(i))
# Out:
# (0, 100)

# %%
# p is low, p = probability of getting 1 for Bernoulli flip
pm.plot_posterior(trace['p'])
pm.plot_posterior(trace['a1'])
pm.plot_posterior(trace['a2'])
pm.plot_posterior(trace['b1'])
pm.plot_posterior(trace['b2'])
# Out:
# /Users/pkarnati/Library/Python/3.6/lib/python/site-packages/arviz/data/base.py:141: SyntaxWarning: More chains (400) than draws (2). Passed array should have shape (chains, draws, *shape)
#   SyntaxWarning,
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x15e4580f0>],
#       dtype=object)

# %%
N = 25
X = X_test
Y = Y_test

new_x = [random.randint(1,101) for i in range(N)]

X_test = new_x


# learning 

with pm.Model() as model:
    siga = 1
    sigb = 10

    print('Creating model...')

    a1 = pm.Normal('a1', mu=1, sigma=siga)
    b1 = pm.Normal('b1', mu=0, sigma=sigb)
    a2 = pm.Normal('a2', mu=-1, sigma=siga)
    b2 = pm.Normal('b2', mu=100, sigma=sigb)

    a = pm.Deterministic('a', tt.stack([a1, a2]))
    b = pm.Deterministic('b', tt.stack([b1, b2]))


    # Dirichlet distribution returns an array of probabilties
    # returns the prior distribution on the categorical distribution
    # alpha = (4,1) states that the categorical distribution is initially
    #         more heavily weighted towards the first value in the categorical
    #         array which is the positive slope
    p = pm.Dirichlet('p', a=np.array([4,1]))

    print('Training on 25 points...')

    for i in range(N):
        z = pm.Categorical('z_%u' % i, p=p)
        mu = a[z]*X[i] + b[z]
        y = pm.Normal('y_%u' % i, mu=mu, sigma=2, observed=Y[i])

    print('Generating test set...')

    for i in range(N):
        z_test = pm.Categorical('z_test_%u' % i, p=p)
        mu_test = a[z_test]*X_test[i] + b[z_test]
        y_test = pm.Normal('y_test_%u' % i, mu=mu_test, sigma=2)

    trace = pm.sample(100)
    neg_traces.append(trace)

print('Generating graph for next generation...')
Y_test = []
for i in range(N):
    y_pos = trace['y_test_%u'%i]
    Y_test.append(np.random.choice(y_pos))
plt.figure()
plt.scatter(X_test, Y_test, color="#FF00FF")
plt.ylim([0,100])
plt.xlim([0,100])
# plt.savefig('neg/gen_%i.jpeg'%(gen))
# Out:
# Creating model...
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# Training on 25 points...
# Generating test set...
# Only 100 samples in chain.
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [y_test_24, y_test_23, y_test_22, y_test_21, y_test_20, y_test_19, y_test_18, y_test_17, y_test_16, y_test_15, y_test_14, y_test_13, y_test_12, y_test_11, y_test_10, y_test_9, y_test_8, y_test_7, y_test_6, y_test_5, y_test_4, y_test_3, y_test_2, y_test_1, y_test_0, p, b2, a2, b1, a1]
# >BinaryGibbsMetropolis: [z_0, z_1, z_2, z_3, z_4, z_5, z_6, z_7, z_8, z_9, z_10, z_11, z_12, z_13, z_14, z_15, z_16, z_17, z_18, z_19, z_20, z_21, z_22, z_23, z_24, z_test_0, z_test_1, z_test_2, z_test_3, z_test_4, z_test_5, z_test_6, z_test_7, z_test_8, z_test_9, z_test_10, z_test_11, z_test_12, z_test_13, z_test_14, z_test_15, z_test_16, z_test_17, z_test_18, z_test_19, z_test_20, z_test_21, z_test_22, z_test_23, z_test_24]
# Sampling 4 chains, 0 divergences: 100%|██████████| 2400/2400 [01:18<00:00, 30.71draws/s]
# /Users/pkarnati/Library/Python/3.6/lib/python/site-packages/xarray/core/nputils.py:223: RuntimeWarning: All-NaN slice encountered
#   result = getattr(npmodule, name)(values, axis=axis, **kwargs)
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The number of effective samples is smaller than 10% for some parameters.
# Generating graph for next generation...
# (0, 100)

# %%
# p is low, p = probability of getting 1 for Bernoulli flip
pm.plot_posterior(trace['p'])
pm.plot_posterior(trace['a1'])
pm.plot_posterior(trace['a2'])
pm.plot_posterior(trace['b1'])
pm.plot_posterior(trace['b2'])
# Out:
# /Users/pkarnati/Library/Python/3.6/lib/python/site-packages/arviz/data/base.py:141: SyntaxWarning: More chains (400) than draws (2). Passed array should have shape (chains, draws, *shape)
#   SyntaxWarning,
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x165144c50>],
#       dtype=object)

# %%
Y_test = []
for i in range(N):
    y_pos = trace['y_test_%u'%i]
    Y_test.append(np.random.choice(y_pos))
plt.figure()
plt.scatter(X_test, Y_test, color="#FF00FF")
plt.ylim([0,100])
plt.xlim([0,100])
# Out:
# (0, 100)

# %%
for gen in range(2, 9):
    N = 25
    X = X_test
    Y = Y_test
    
    new_x = [random.randint(1,101) for i in range(N)]

    X_test = new_x


    # learning 

    with pm.Model() as model:
        siga = 1
        sigb = 10

        print('Creating model...')

        a1 = pm.Normal('a1', mu=1, sigma=siga)
        b1 = pm.Normal('b1', mu=0, sigma=sigb)
        a2 = pm.Normal('a2', mu=-1, sigma=siga)
        b2 = pm.Normal('b2', mu=100, sigma=sigb)

        a = pm.Deterministic('a', tt.stack([a1, a2]))
        b = pm.Deterministic('b', tt.stack([b1, b2]))


        # Dirichlet distribution returns an array of probabilties
        # returns the prior distribution on the categorical distribution
        # alpha = (4,1) states that the categorical distribution is initially
        #         more heavily weighted towards the first value in the categorical
        #         array which is the positive slope
        p = pm.Dirichlet('p', a=np.array([4,1]))

        print('Training on 25 points...')

        for i in range(N):
            z = pm.Categorical('z_%u' % i, p=p)
            mu = a[z]*X[i] + b[z]
            y = pm.Normal('y_%u' % i, mu=mu, sigma=2, observed=Y[i])

        print('Generating test set...')

        for i in range(N):
            z_test = pm.Categorical('z_test_%u' % i, p=p)
            mu_test = a[z_test]*X_test[i] + b[z_test]
            y_test = pm.Normal('y_test_%u' % i, mu=mu_test, sigma=2)

        trace = pm.sample(100)

    print('Generating graph for next generation...')
    Y_test = []
    for i in range(N):
        y_pos = trace['y_test_%u'%i]
        Y_test.append(np.random.choice(y_pos))
    plt.figure()
    plt.scatter(X_test, Y_test, color="#FF00FF")
    plt.ylim([0,100])
    plt.xlim([0,100])
    plt.savefig('neg/gen_%i.jpeg'%(gen))
# Out:
# Creating model...
# Training on 25 points...
# Generating test set...
# Only 100 samples in chain.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [y_test_24, y_test_23, y_test_22, y_test_21, y_test_20, y_test_19, y_test_18, y_test_17, y_test_16, y_test_15, y_test_14, y_test_13, y_test_12, y_test_11, y_test_10, y_test_9, y_test_8, y_test_7, y_test_6, y_test_5, y_test_4, y_test_3, y_test_2, y_test_1, y_test_0, p, b2, a2, b1, a1]
# >BinaryGibbsMetropolis: [z_0, z_1, z_2, z_3, z_4, z_5, z_6, z_7, z_8, z_9, z_10, z_11, z_12, z_13, z_14, z_15, z_16, z_17, z_18, z_19, z_20, z_21, z_22, z_23, z_24, z_test_0, z_test_1, z_test_2, z_test_3, z_test_4, z_test_5, z_test_6, z_test_7, z_test_8, z_test_9, z_test_10, z_test_11, z_test_12, z_test_13, z_test_14, z_test_15, z_test_16, z_test_17, z_test_18, z_test_19, z_test_20, z_test_21, z_test_22, z_test_23, z_test_24]
# Sampling 4 chains, 0 divergences: 100%|██████████| 2400/2400 [00:59<00:00, 40.34draws/s]
# /Users/pkarnati/Library/Python/3.6/lib/python/site-packages/xarray/core/nputils.py:223: RuntimeWarning: All-NaN slice encountered
#   result = getattr(npmodule, name)(values, axis=axis, **kwargs)
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The number of effective samples is smaller than 10% for some parameters.
# Generating graph for next generation...
# Creating model...
# Training on 25 points...
# Generating test set...
# Only 100 samples in chain.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [y_test_24, y_test_23, y_test_22, y_test_21, y_test_20, y_test_19, y_test_18, y_test_17, y_test_16, y_test_15, y_test_14, y_test_13, y_test_12, y_test_11, y_test_10, y_test_9, y_test_8, y_test_7, y_test_6, y_test_5, y_test_4, y_test_3, y_test_2, y_test_1, y_test_0, p, b2, a2, b1, a1]
# >BinaryGibbsMetropolis: [z_0, z_1, z_2, z_3, z_4, z_5, z_6, z_7, z_8, z_9, z_10, z_11, z_12, z_13, z_14, z_15, z_16, z_17, z_18, z_19, z_20, z_21, z_22, z_23, z_24, z_test_0, z_test_1, z_test_2, z_test_3, z_test_4, z_test_5, z_test_6, z_test_7, z_test_8, z_test_9, z_test_10, z_test_11, z_test_12, z_test_13, z_test_14, z_test_15, z_test_16, z_test_17, z_test_18, z_test_19, z_test_20, z_test_21, z_test_22, z_test_23, z_test_24]
# Sampling 4 chains, 4 divergences: 100%|██████████| 2400/2400 [01:18<00:00, 30.64draws/s]
# /Users/pkarnati/Library/Python/3.6/lib/python/site-packages/xarray/core/nputils.py:223: RuntimeWarning: All-NaN slice encountered
#   result = getattr(npmodule, name)(values, axis=axis, **kwargs)
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The number of effective samples is smaller than 10% for some parameters.
# Generating graph for next generation...
# Creating model...
# Training on 25 points...
# Generating test set...
# Only 100 samples in chain.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [y_test_24, y_test_23, y_test_22, y_test_21, y_test_20, y_test_19, y_test_18, y_test_17, y_test_16, y_test_15, y_test_14, y_test_13, y_test_12, y_test_11, y_test_10, y_test_9, y_test_8, y_test_7, y_test_6, y_test_5, y_test_4, y_test_3, y_test_2, y_test_1, y_test_0, p, b2, a2, b1, a1]
# >BinaryGibbsMetropolis: [z_0, z_1, z_2, z_3, z_4, z_5, z_6, z_7, z_8, z_9, z_10, z_11, z_12, z_13, z_14, z_15, z_16, z_17, z_18, z_19, z_20, z_21, z_22, z_23, z_24, z_test_0, z_test_1, z_test_2, z_test_3, z_test_4, z_test_5, z_test_6, z_test_7, z_test_8, z_test_9, z_test_10, z_test_11, z_test_12, z_test_13, z_test_14, z_test_15, z_test_16, z_test_17, z_test_18, z_test_19, z_test_20, z_test_21, z_test_22, z_test_23, z_test_24]
# Sampling 4 chains, 23 divergences: 100%|██████████| 2400/2400 [01:20<00:00, 30.00draws/s]
# /Users/pkarnati/Library/Python/3.6/lib/python/site-packages/xarray/core/nputils.py:223: RuntimeWarning: All-NaN slice encountered
#   result = getattr(npmodule, name)(values, axis=axis, **kwargs)
# There were 6 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.671839344311018, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 11 divergences after tuning. Increase `target_accept` or reparameterize.
# The number of effective samples is smaller than 25% for some parameters.
# Generating graph for next generation...
# Creating model...
# Training on 25 points...
# Generating test set...
# Only 100 samples in chain.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [y_test_24, y_test_23, y_test_22, y_test_21, y_test_20, y_test_19, y_test_18, y_test_17, y_test_16, y_test_15, y_test_14, y_test_13, y_test_12, y_test_11, y_test_10, y_test_9, y_test_8, y_test_7, y_test_6, y_test_5, y_test_4, y_test_3, y_test_2, y_test_1, y_test_0, p, b2, a2, b1, a1]
# >BinaryGibbsMetropolis: [z_0, z_1, z_2, z_3, z_4, z_5, z_6, z_7, z_8, z_9, z_10, z_11, z_12, z_13, z_14, z_15, z_16, z_17, z_18, z_19, z_20, z_21, z_22, z_23, z_24, z_test_0, z_test_1, z_test_2, z_test_3, z_test_4, z_test_5, z_test_6, z_test_7, z_test_8, z_test_9, z_test_10, z_test_11, z_test_12, z_test_13, z_test_14, z_test_15, z_test_16, z_test_17, z_test_18, z_test_19, z_test_20, z_test_21, z_test_22, z_test_23, z_test_24]
# Sampling 4 chains, 18 divergences: 100%|██████████| 2400/2400 [01:17<00:00, 31.02draws/s]
# /Users/pkarnati/Library/Python/3.6/lib/python/site-packages/xarray/core/nputils.py:223: RuntimeWarning: All-NaN slice encountered
#   result = getattr(npmodule, name)(values, axis=axis, **kwargs)
# There were 4 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 5 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 5 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 4 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.8825759925009465, but should be close to 0.8. Try to increase the number of tuning steps.
# The rhat statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# Generating graph for next generation...
# Creating model...
# Training on 25 points...
# Generating test set...
# Only 100 samples in chain.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [y_test_24, y_test_23, y_test_22, y_test_21, y_test_20, y_test_19, y_test_18, y_test_17, y_test_16, y_test_15, y_test_14, y_test_13, y_test_12, y_test_11, y_test_10, y_test_9, y_test_8, y_test_7, y_test_6, y_test_5, y_test_4, y_test_3, y_test_2, y_test_1, y_test_0, p, b2, a2, b1, a1]
# >BinaryGibbsMetropolis: [z_0, z_1, z_2, z_3, z_4, z_5, z_6, z_7, z_8, z_9, z_10, z_11, z_12, z_13, z_14, z_15, z_16, z_17, z_18, z_19, z_20, z_21, z_22, z_23, z_24, z_test_0, z_test_1, z_test_2, z_test_3, z_test_4, z_test_5, z_test_6, z_test_7, z_test_8, z_test_9, z_test_10, z_test_11, z_test_12, z_test_13, z_test_14, z_test_15, z_test_16, z_test_17, z_test_18, z_test_19, z_test_20, z_test_21, z_test_22, z_test_23, z_test_24]
# Sampling 4 chains, 15 divergences: 100%|██████████| 2400/2400 [01:20<00:00, 29.85draws/s]
# /Users/pkarnati/Library/Python/3.6/lib/python/site-packages/xarray/core/nputils.py:223: RuntimeWarning: All-NaN slice encountered
#   result = getattr(npmodule, name)(values, axis=axis, **kwargs)
# The acceptance probability does not match the target. It is 0.9537557486220661, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 10 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.8990837053093625, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# The number of effective samples is smaller than 25% for some parameters.
# Generating graph for next generation...
# Creating model...
# Training on 25 points...
# Generating test set...
# Only 100 samples in chain.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [y_test_24, y_test_23, y_test_22, y_test_21, y_test_20, y_test_19, y_test_18, y_test_17, y_test_16, y_test_15, y_test_14, y_test_13, y_test_12, y_test_11, y_test_10, y_test_9, y_test_8, y_test_7, y_test_6, y_test_5, y_test_4, y_test_3, y_test_2, y_test_1, y_test_0, p, b2, a2, b1, a1]
# >BinaryGibbsMetropolis: [z_0, z_1, z_2, z_3, z_4, z_5, z_6, z_7, z_8, z_9, z_10, z_11, z_12, z_13, z_14, z_15, z_16, z_17, z_18, z_19, z_20, z_21, z_22, z_23, z_24, z_test_0, z_test_1, z_test_2, z_test_3, z_test_4, z_test_5, z_test_6, z_test_7, z_test_8, z_test_9, z_test_10, z_test_11, z_test_12, z_test_13, z_test_14, z_test_15, z_test_16, z_test_17, z_test_18, z_test_19, z_test_20, z_test_21, z_test_22, z_test_23, z_test_24]
# Sampling 4 chains, 21 divergences: 100%|██████████| 2400/2400 [01:33<00:00, 25.59draws/s]
# /Users/pkarnati/Library/Python/3.6/lib/python/site-packages/xarray/core/nputils.py:223: RuntimeWarning: All-NaN slice encountered
#   result = getattr(npmodule, name)(values, axis=axis, **kwargs)
# There were 4 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.8820712822804877, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 10 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 4 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.8809699125591542, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.910952426287409, but should be close to 0.8. Try to increase the number of tuning steps.
# Generating graph for next generation...
# Creating model...
# Training on 25 points...
# Generating test set...
# Only 100 samples in chain.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [y_test_24, y_test_23, y_test_22, y_test_21, y_test_20, y_test_19, y_test_18, y_test_17, y_test_16, y_test_15, y_test_14, y_test_13, y_test_12, y_test_11, y_test_10, y_test_9, y_test_8, y_test_7, y_test_6, y_test_5, y_test_4, y_test_3, y_test_2, y_test_1, y_test_0, p, b2, a2, b1, a1]
# >BinaryGibbsMetropolis: [z_0, z_1, z_2, z_3, z_4, z_5, z_6, z_7, z_8, z_9, z_10, z_11, z_12, z_13, z_14, z_15, z_16, z_17, z_18, z_19, z_20, z_21, z_22, z_23, z_24, z_test_0, z_test_1, z_test_2, z_test_3, z_test_4, z_test_5, z_test_6, z_test_7, z_test_8, z_test_9, z_test_10, z_test_11, z_test_12, z_test_13, z_test_14, z_test_15, z_test_16, z_test_17, z_test_18, z_test_19, z_test_20, z_test_21, z_test_22, z_test_23, z_test_24]
# Sampling 4 chains, 34 divergences: 100%|██████████| 2400/2400 [01:15<00:00, 31.79draws/s]
# /Users/pkarnati/Library/Python/3.6/lib/python/site-packages/xarray/core/nputils.py:223: RuntimeWarning: All-NaN slice encountered
#   result = getattr(npmodule, name)(values, axis=axis, **kwargs)
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.9638538262732417, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 4 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.8842404261100855, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 7 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 21 divergences after tuning. Increase `target_accept` or reparameterize.
# The number of effective samples is smaller than 25% for some parameters.
# Generating graph for next generation...

# %%
pm.plot_posterior(trace['p'])
pm.plot_posterior(trace['a1'])
pm.plot_posterior(trace['a2'])
pm.plot_posterior(trace['b1'])
pm.plot_posterior(trace['b2'])
# Out:
# /Users/pkarnati/Library/Python/3.6/lib/python/site-packages/arviz/data/base.py:141: SyntaxWarning: More chains (400) than draws (2). Passed array should have shape (chains, draws, *shape)
#   SyntaxWarning,
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x136430780>],
#       dtype=object)

# %% [markdown]
# Second function

# %%
xs_1, ys_1 = plot_function(2, plot=True, num_points=50)
xs = list(np.copy(xs_1))
ys = list(np.copy(ys_1))

# %%
train_x = []
train_y = []
for i in range(25):
    ind = random.randint(0, len(xs)-1)
    x = xs.pop(ind)
    y = ys.pop(ind)
    
    train_x.append(x)
    train_y.append(y)
plt.scatter(train_x, train_y)
plt.savefig('poly/gen_0.jpeg')

# %%
len(xs), len(ys), len(train_x), len(train_y)
# Out:
# (25, 25, 25, 25)

# %%
poly_traces = []

# %%
N= 25
X = train_x
Y = train_y

X_test = xs


# learning 

with pm.Model() as model:
    siga = 1
    sigb = 10
    
    print('Creating model...')
    
    a1 = pm.Normal('a1', mu=1, sigma=siga)
    b1 = pm.Normal('b1', mu=0, sigma=sigb)
    a2 = pm.Normal('a2', mu=-1, sigma=siga)
    b2 = pm.Normal('b2', mu=100, sigma=sigb)

    a = pm.Deterministic('a', tt.stack([a1, a2]))
    b = pm.Deterministic('b', tt.stack([b1, b2]))


    # Dirichlet distribution returns an array of probabilties
    # returns the prior distribution on the categorical distribution
    # alpha = (4,1) states that the categorical distribution is initially
    #         more heavily weighted towards the first value in the categorical
    #         array which is the positive slope
    p = pm.Dirichlet('p', a=np.array([2,1]))

    print('Training on 25 points...')
    
    for i in range(N):
        z = pm.Categorical('z_%u' % i, p=p)
        mu = a[z]*X[i] + b[z]
        y = pm.Normal('y_%u' % i, mu=mu, sigma=2, observed=Y[i])
        
    print('Generating test set...')
    
    for i in range(N):
        z_test = pm.Categorical('z_test_%u' % i, p=p)
        mu_test = a[z_test]*X_test[i] + b[z_test]
        y_test = pm.Normal('y_test_%u' % i, mu=mu_test, sigma=2)
    
    trace = pm.sample(100)
    poly_traces.append(trace)
        
print('Generating graph for next generation...')
Y_test = []
for i in range(N):
    y_pos = trace['y_test_%u'%i]
    Y_test.append(np.random.choice(y_pos))
plt.figure()
plt.scatter(X_test, Y_test, color="#FF00FF")
plt.ylim([0,100])
plt.xlim([0,100])
plt.savefig('poly/gen_1.jpeg')
# Out:
# Creating model...
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# Training on 25 points...
# Generating test set...
# Only 100 samples in chain.
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [y_test_24, y_test_23, y_test_22, y_test_21, y_test_20, y_test_19, y_test_18, y_test_17, y_test_16, y_test_15, y_test_14, y_test_13, y_test_12, y_test_11, y_test_10, y_test_9, y_test_8, y_test_7, y_test_6, y_test_5, y_test_4, y_test_3, y_test_2, y_test_1, y_test_0, p, b2, a2, b1, a1]
# >BinaryGibbsMetropolis: [z_0, z_1, z_2, z_3, z_4, z_5, z_6, z_7, z_8, z_9, z_10, z_11, z_12, z_13, z_14, z_15, z_16, z_17, z_18, z_19, z_20, z_21, z_22, z_23, z_24, z_test_0, z_test_1, z_test_2, z_test_3, z_test_4, z_test_5, z_test_6, z_test_7, z_test_8, z_test_9, z_test_10, z_test_11, z_test_12, z_test_13, z_test_14, z_test_15, z_test_16, z_test_17, z_test_18, z_test_19, z_test_20, z_test_21, z_test_22, z_test_23, z_test_24]
# Sampling 4 chains, 2 divergences: 100%|██████████| 2400/2400 [01:14<00:00, 32.23draws/s]
# /Users/pkarnati/Library/Python/3.6/lib/python/site-packages/xarray/core/nputils.py:223: RuntimeWarning: All-NaN slice encountered
#   result = getattr(npmodule, name)(values, axis=axis, **kwargs)
# The acceptance probability does not match the target. It is 0.8843680405210396, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9003598051811302, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9052570339194126, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8878106450019816, but should be close to 0.8. Try to increase the number of tuning steps.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The number of effective samples is smaller than 10% for some parameters.
# Generating graph for next generation...

# %%
Y_test = []
for i in range(N):
    y_pos = trace['y_test_%u'%i]
    Y_test.append(np.random.choice(y_pos))
plt.figure()
plt.scatter(X_test, Y_test, color="#FF00FF")
plt.ylim([0,100])
plt.xlim([0,100])
plt.savefig('poly/gen_1.jpeg')

# %%
# p is low, p = probability of getting 1 for Bernoulli flip
pm.plot_posterior(trace['p'])
pm.plot_posterior(trace['a1'])
pm.plot_posterior(trace['a2'])
pm.plot_posterior(trace['b1'])
pm.plot_posterior(trace['b2'])
# Out:
# /Users/pkarnati/Library/Python/3.6/lib/python/site-packages/arviz/data/base.py:141: SyntaxWarning: More chains (400) than draws (2). Passed array should have shape (chains, draws, *shape)
#   SyntaxWarning,
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1248394e0>],
#       dtype=object)

# %%
for gen in range(2, 9):
    N = 25
    X = X_test
    Y = Y_test
    
    new_x = [random.randint(1,101) for i in range(N)]

    X_test = new_x


    # learning 

    with pm.Model() as model:
        siga = 1
        sigb = 10

        print('Creating model...')

        a1 = pm.Normal('a1', mu=1, sigma=siga)
        b1 = pm.Normal('b1', mu=0, sigma=sigb)
        a2 = pm.Normal('a2', mu=-1, sigma=siga)
        b2 = pm.Normal('b2', mu=100, sigma=sigb)

        a = pm.Deterministic('a', tt.stack([a1, a2]))
        b = pm.Deterministic('b', tt.stack([b1, b2]))


        # Dirichlet distribution returns an array of probabilties
        # returns the prior distribution on the categorical distribution
        # alpha = (4,1) states that the categorical distribution is initially
        #         more heavily weighted towards the first value in the categorical
        #         array which is the positive slope
        p = pm.Dirichlet('p', a=np.array([4,1]))

        print('Training on 25 points...')

        for i in range(N):
            z = pm.Categorical('z_%u' % i, p=p)
            mu = a[z]*X[i] + b[z]
            y = pm.Normal('y_%u' % i, mu=mu, sigma=2, observed=Y[i])

        print('Generating test set...')

        for i in range(N):
            z_test = pm.Categorical('z_test_%u' % i, p=p)
            mu_test = a[z_test]*X_test[i] + b[z_test]
            y_test = pm.Normal('y_test_%u' % i, mu=mu_test, sigma=2)

        trace = pm.sample(100)
        poly_traces.append(trace)

    print('Generating graph for next generation...')
    Y_test = []
    for i in range(N):
        y_pos = trace['y_test_%u'%i]
        Y_test.append(np.random.choice(y_pos))
    plt.figure()
    plt.scatter(X_test, Y_test, color="#FF00FF")
    plt.ylim([0,100])
    plt.xlim([0,100])
    plt.savefig('poly/gen_%i.jpeg'%(gen))
# Out:
# Creating model...
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# Training on 25 points...
# Generating test set...
# Only 100 samples in chain.
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [y_test_24, y_test_23, y_test_22, y_test_21, y_test_20, y_test_19, y_test_18, y_test_17, y_test_16, y_test_15, y_test_14, y_test_13, y_test_12, y_test_11, y_test_10, y_test_9, y_test_8, y_test_7, y_test_6, y_test_5, y_test_4, y_test_3, y_test_2, y_test_1, y_test_0, p, b2, a2, b1, a1]
# >BinaryGibbsMetropolis: [z_0, z_1, z_2, z_3, z_4, z_5, z_6, z_7, z_8, z_9, z_10, z_11, z_12, z_13, z_14, z_15, z_16, z_17, z_18, z_19, z_20, z_21, z_22, z_23, z_24, z_test_0, z_test_1, z_test_2, z_test_3, z_test_4, z_test_5, z_test_6, z_test_7, z_test_8, z_test_9, z_test_10, z_test_11, z_test_12, z_test_13, z_test_14, z_test_15, z_test_16, z_test_17, z_test_18, z_test_19, z_test_20, z_test_21, z_test_22, z_test_23, z_test_24]
# Sampling 4 chains, 0 divergences: 100%|██████████| 2400/2400 [01:09<00:00, 34.47draws/s]
# /Users/pkarnati/Library/Python/3.6/lib/python/site-packages/xarray/core/nputils.py:223: RuntimeWarning: All-NaN slice encountered
#   result = getattr(npmodule, name)(values, axis=axis, **kwargs)
# The acceptance probability does not match the target. It is 0.8871314178333752, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9064618459043983, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8811330180979655, but should be close to 0.8. Try to increase the number of tuning steps.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The number of effective samples is smaller than 10% for some parameters.
# Generating graph for next generation...
# Creating model...
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# Training on 25 points...
# Generating test set...
# Only 100 samples in chain.
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [y_test_24, y_test_23, y_test_22, y_test_21, y_test_20, y_test_19, y_test_18, y_test_17, y_test_16, y_test_15, y_test_14, y_test_13, y_test_12, y_test_11, y_test_10, y_test_9, y_test_8, y_test_7, y_test_6, y_test_5, y_test_4, y_test_3, y_test_2, y_test_1, y_test_0, p, b2, a2, b1, a1]
# >BinaryGibbsMetropolis: [z_0, z_1, z_2, z_3, z_4, z_5, z_6, z_7, z_8, z_9, z_10, z_11, z_12, z_13, z_14, z_15, z_16, z_17, z_18, z_19, z_20, z_21, z_22, z_23, z_24, z_test_0, z_test_1, z_test_2, z_test_3, z_test_4, z_test_5, z_test_6, z_test_7, z_test_8, z_test_9, z_test_10, z_test_11, z_test_12, z_test_13, z_test_14, z_test_15, z_test_16, z_test_17, z_test_18, z_test_19, z_test_20, z_test_21, z_test_22, z_test_23, z_test_24]
# Sampling 4 chains, 8 divergences: 100%|██████████| 2400/2400 [01:11<00:00, 33.73draws/s]
# /Users/pkarnati/Library/Python/3.6/lib/python/site-packages/xarray/core/nputils.py:223: RuntimeWarning: All-NaN slice encountered
#   result = getattr(npmodule, name)(values, axis=axis, **kwargs)
# There were 8 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.9267659750975922, but should be close to 0.8. Try to increase the number of tuning steps.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The number of effective samples is smaller than 10% for some parameters.
# Generating graph for next generation...
# Creating model...
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# Training on 25 points...
# Generating test set...
# Only 100 samples in chain.
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [y_test_24, y_test_23, y_test_22, y_test_21, y_test_20, y_test_19, y_test_18, y_test_17, y_test_16, y_test_15, y_test_14, y_test_13, y_test_12, y_test_11, y_test_10, y_test_9, y_test_8, y_test_7, y_test_6, y_test_5, y_test_4, y_test_3, y_test_2, y_test_1, y_test_0, p, b2, a2, b1, a1]
# >BinaryGibbsMetropolis: [z_0, z_1, z_2, z_3, z_4, z_5, z_6, z_7, z_8, z_9, z_10, z_11, z_12, z_13, z_14, z_15, z_16, z_17, z_18, z_19, z_20, z_21, z_22, z_23, z_24, z_test_0, z_test_1, z_test_2, z_test_3, z_test_4, z_test_5, z_test_6, z_test_7, z_test_8, z_test_9, z_test_10, z_test_11, z_test_12, z_test_13, z_test_14, z_test_15, z_test_16, z_test_17, z_test_18, z_test_19, z_test_20, z_test_21, z_test_22, z_test_23, z_test_24]
# Sampling 4 chains, 15 divergences: 100%|██████████| 2400/2400 [01:22<00:00, 29.26draws/s]
# /Users/pkarnati/Library/Python/3.6/lib/python/site-packages/xarray/core/nputils.py:223: RuntimeWarning: All-NaN slice encountered
#   result = getattr(npmodule, name)(values, axis=axis, **kwargs)
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.8852434722100724, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 6 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# Generating graph for next generation...
# Creating model...
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# Training on 25 points...
# Generating test set...
# Only 100 samples in chain.
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [y_test_24, y_test_23, y_test_22, y_test_21, y_test_20, y_test_19, y_test_18, y_test_17, y_test_16, y_test_15, y_test_14, y_test_13, y_test_12, y_test_11, y_test_10, y_test_9, y_test_8, y_test_7, y_test_6, y_test_5, y_test_4, y_test_3, y_test_2, y_test_1, y_test_0, p, b2, a2, b1, a1]
# >BinaryGibbsMetropolis: [z_0, z_1, z_2, z_3, z_4, z_5, z_6, z_7, z_8, z_9, z_10, z_11, z_12, z_13, z_14, z_15, z_16, z_17, z_18, z_19, z_20, z_21, z_22, z_23, z_24, z_test_0, z_test_1, z_test_2, z_test_3, z_test_4, z_test_5, z_test_6, z_test_7, z_test_8, z_test_9, z_test_10, z_test_11, z_test_12, z_test_13, z_test_14, z_test_15, z_test_16, z_test_17, z_test_18, z_test_19, z_test_20, z_test_21, z_test_22, z_test_23, z_test_24]
# Sampling 4 chains, 25 divergences: 100%|██████████| 2400/2400 [01:15<00:00, 31.74draws/s]
# /Users/pkarnati/Library/Python/3.6/lib/python/site-packages/xarray/core/nputils.py:223: RuntimeWarning: All-NaN slice encountered
#   result = getattr(npmodule, name)(values, axis=axis, **kwargs)
# There were 13 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 4 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.8799800193748186, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 4 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 4 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.8939706057623155, but should be close to 0.8. Try to increase the number of tuning steps.
# The rhat statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# Generating graph for next generation...
# Creating model...
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# Training on 25 points...
# Generating test set...
# Only 100 samples in chain.
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [y_test_24, y_test_23, y_test_22, y_test_21, y_test_20, y_test_19, y_test_18, y_test_17, y_test_16, y_test_15, y_test_14, y_test_13, y_test_12, y_test_11, y_test_10, y_test_9, y_test_8, y_test_7, y_test_6, y_test_5, y_test_4, y_test_3, y_test_2, y_test_1, y_test_0, p, b2, a2, b1, a1]
# >BinaryGibbsMetropolis: [z_0, z_1, z_2, z_3, z_4, z_5, z_6, z_7, z_8, z_9, z_10, z_11, z_12, z_13, z_14, z_15, z_16, z_17, z_18, z_19, z_20, z_21, z_22, z_23, z_24, z_test_0, z_test_1, z_test_2, z_test_3, z_test_4, z_test_5, z_test_6, z_test_7, z_test_8, z_test_9, z_test_10, z_test_11, z_test_12, z_test_13, z_test_14, z_test_15, z_test_16, z_test_17, z_test_18, z_test_19, z_test_20, z_test_21, z_test_22, z_test_23, z_test_24]
# Sampling 4 chains, 11 divergences: 100%|██████████| 2400/2400 [01:19<00:00, 30.08draws/s]
# /Users/pkarnati/Library/Python/3.6/lib/python/site-packages/xarray/core/nputils.py:223: RuntimeWarning: All-NaN slice encountered
#   result = getattr(npmodule, name)(values, axis=axis, **kwargs)
# There were 4 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.8966537574070549, but should be close to 0.8. Try to increase the number of tuning steps.
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.9097860015293349, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.8945315876082585, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.924903369000007, but should be close to 0.8. Try to increase the number of tuning steps.
# Generating graph for next generation...
# Creating model...
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# Training on 25 points...
# Generating test set...
# Only 100 samples in chain.
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [y_test_24, y_test_23, y_test_22, y_test_21, y_test_20, y_test_19, y_test_18, y_test_17, y_test_16, y_test_15, y_test_14, y_test_13, y_test_12, y_test_11, y_test_10, y_test_9, y_test_8, y_test_7, y_test_6, y_test_5, y_test_4, y_test_3, y_test_2, y_test_1, y_test_0, p, b2, a2, b1, a1]
# >BinaryGibbsMetropolis: [z_0, z_1, z_2, z_3, z_4, z_5, z_6, z_7, z_8, z_9, z_10, z_11, z_12, z_13, z_14, z_15, z_16, z_17, z_18, z_19, z_20, z_21, z_22, z_23, z_24, z_test_0, z_test_1, z_test_2, z_test_3, z_test_4, z_test_5, z_test_6, z_test_7, z_test_8, z_test_9, z_test_10, z_test_11, z_test_12, z_test_13, z_test_14, z_test_15, z_test_16, z_test_17, z_test_18, z_test_19, z_test_20, z_test_21, z_test_22, z_test_23, z_test_24]
# Sampling 4 chains, 10 divergences: 100%|██████████| 2400/2400 [01:36<00:00, 24.85draws/s]
# /Users/pkarnati/Library/Python/3.6/lib/python/site-packages/xarray/core/nputils.py:223: RuntimeWarning: All-NaN slice encountered
#   result = getattr(npmodule, name)(values, axis=axis, **kwargs)
# There were 4 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.9080459420859345, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 6 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.9258002364522644, but should be close to 0.8. Try to increase the number of tuning steps.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The number of effective samples is smaller than 10% for some parameters.
# Generating graph for next generation...
# Creating model...
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# Training on 25 points...
# Generating test set...
# Only 100 samples in chain.
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [y_test_24, y_test_23, y_test_22, y_test_21, y_test_20, y_test_19, y_test_18, y_test_17, y_test_16, y_test_15, y_test_14, y_test_13, y_test_12, y_test_11, y_test_10, y_test_9, y_test_8, y_test_7, y_test_6, y_test_5, y_test_4, y_test_3, y_test_2, y_test_1, y_test_0, p, b2, a2, b1, a1]
# >BinaryGibbsMetropolis: [z_0, z_1, z_2, z_3, z_4, z_5, z_6, z_7, z_8, z_9, z_10, z_11, z_12, z_13, z_14, z_15, z_16, z_17, z_18, z_19, z_20, z_21, z_22, z_23, z_24, z_test_0, z_test_1, z_test_2, z_test_3, z_test_4, z_test_5, z_test_6, z_test_7, z_test_8, z_test_9, z_test_10, z_test_11, z_test_12, z_test_13, z_test_14, z_test_15, z_test_16, z_test_17, z_test_18, z_test_19, z_test_20, z_test_21, z_test_22, z_test_23, z_test_24]
# Sampling 4 chains, 0 divergences: 100%|██████████| 2400/2400 [01:04<00:00, 37.02draws/s]
# /Users/pkarnati/Library/Python/3.6/lib/python/site-packages/xarray/core/nputils.py:223: RuntimeWarning: All-NaN slice encountered
#   result = getattr(npmodule, name)(values, axis=axis, **kwargs)
# The acceptance probability does not match the target. It is 0.8862383156345529, but should be close to 0.8. Try to increase the number of tuning steps.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The number of effective samples is smaller than 10% for some parameters.
# Generating graph for next generation...

# %% [markdown]
# Third Function

# %%
xs_1, ys_1 = plot_function(3, plot=True, num_points=50)
xs = list(np.copy(xs_1))
ys = list(np.copy(ys_1))

# %%
train_x = []
train_y = []
for i in range(25):
    ind = random.randint(0, len(xs)-1)
    x = xs.pop(ind)
    y = ys.pop(ind)
    
    train_x.append(x)
    train_y.append(y)
plt.scatter(train_x, train_y)
plt.savefig('ran/gen_0.jpeg')

# %%
len(xs), len(ys), len(train_x), len(train_y)
# Out:
# (25, 25, 25, 25)

# %%
ran_traces = []

# %%
N= 25
X = train_x
Y = train_y

X_test = xs


# learning 

with pm.Model() as model:
    siga = 1
    sigb = 10
    
    print('Creating model...')
    
    a1 = pm.Normal('a1', mu=1, sigma=siga)
    b1 = pm.Normal('b1', mu=0, sigma=sigb)
    a2 = pm.Normal('a2', mu=-1, sigma=siga)
    b2 = pm.Normal('b2', mu=100, sigma=sigb)

    a = pm.Deterministic('a', tt.stack([a1, a2]))
    b = pm.Deterministic('b', tt.stack([b1, b2]))


    # Dirichlet distribution returns an array of probabilties
    # returns the prior distribution on the categorical distribution
    # alpha = (4,1) states that the categorical distribution is initially
    #         more heavily weighted towards the first value in the categorical
    #         array which is the positive slope
    p = pm.Dirichlet('p', a=np.array([2,1]))

    print('Training on 25 points...')
    
    for i in range(N):
        z = pm.Categorical('z_%u' % i, p=p)
        mu = a[z]*X[i] + b[z]
        y = pm.Normal('y_%u' % i, mu=mu, sigma=2, observed=Y[i])
        
    print('Generating test set...')
    
    for i in range(N):
        z_test = pm.Categorical('z_test_%u' % i, p=p)
        mu_test = a[z_test]*X_test[i] + b[z_test]
        y_test = pm.Normal('y_test_%u' % i, mu=mu_test, sigma=2)
    
    trace = pm.sample(100)
    ran_traces.append(trace)
        
print('Generating graph for next generation...')
Y_test = []
for i in range(N):
    y_pos = trace['y_test_%u'%i]
    Y_test.append(np.random.choice(y_pos))
plt.figure()
plt.scatter(X_test, Y_test, color="#FF00FF")
plt.ylim([0,100])
plt.xlim([0,100])
plt.savefig('ran/gen_1.jpeg')
# Out:
# Creating model...
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# Training on 25 points...
# Generating test set...
# Only 100 samples in chain.
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [y_test_24, y_test_23, y_test_22, y_test_21, y_test_20, y_test_19, y_test_18, y_test_17, y_test_16, y_test_15, y_test_14, y_test_13, y_test_12, y_test_11, y_test_10, y_test_9, y_test_8, y_test_7, y_test_6, y_test_5, y_test_4, y_test_3, y_test_2, y_test_1, y_test_0, p, b2, a2, b1, a1]
# >BinaryGibbsMetropolis: [z_0, z_1, z_2, z_3, z_4, z_5, z_6, z_7, z_8, z_9, z_10, z_11, z_12, z_13, z_14, z_15, z_16, z_17, z_18, z_19, z_20, z_21, z_22, z_23, z_24, z_test_0, z_test_1, z_test_2, z_test_3, z_test_4, z_test_5, z_test_6, z_test_7, z_test_8, z_test_9, z_test_10, z_test_11, z_test_12, z_test_13, z_test_14, z_test_15, z_test_16, z_test_17, z_test_18, z_test_19, z_test_20, z_test_21, z_test_22, z_test_23, z_test_24]
# Sampling 4 chains, 0 divergences: 100%|██████████| 2400/2400 [00:59<00:00, 40.62draws/s]
# /Users/pkarnati/Library/Python/3.6/lib/python/site-packages/xarray/core/nputils.py:223: RuntimeWarning: All-NaN slice encountered
#   result = getattr(npmodule, name)(values, axis=axis, **kwargs)
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The number of effective samples is smaller than 10% for some parameters.
# Generating graph for next generation...

# %%
# p is low, p = probability of getting 1 for Bernoulli flip
pm.plot_posterior(trace['p'])
pm.plot_posterior(trace['a1'])
pm.plot_posterior(trace['a2'])
pm.plot_posterior(trace['b1'])
pm.plot_posterior(trace['b2'])
# Out:
# /Users/pkarnati/Library/Python/3.6/lib/python/site-packages/arviz/data/base.py:141: SyntaxWarning: More chains (400) than draws (2). Passed array should have shape (chains, draws, *shape)
#   SyntaxWarning,
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1303d8dd8>],
#       dtype=object)

# %%
for gen in range(2, 9):
    N = 25
    X = X_test
    Y = Y_test
    
    new_x = [random.randint(1,101) for i in range(N)]

    X_test = new_x


    # learning 

    with pm.Model() as model:
        siga = 1
        sigb = 10

        print('Creating model...')

        a1 = pm.Normal('a1', mu=1, sigma=siga)
        b1 = pm.Normal('b1', mu=0, sigma=sigb)
        a2 = pm.Normal('a2', mu=-1, sigma=siga)
        b2 = pm.Normal('b2', mu=100, sigma=sigb)

        a = pm.Deterministic('a', tt.stack([a1, a2]))
        b = pm.Deterministic('b', tt.stack([b1, b2]))


        # Dirichlet distribution returns an array of probabilties
        # returns the prior distribution on the categorical distribution
        # alpha = (4,1) states that the categorical distribution is initially
        #         more heavily weighted towards the first value in the categorical
        #         array which is the positive slope
        p = pm.Dirichlet('p', a=np.array([4,1]))

        print('Training on 25 points...')

        for i in range(N):
            z = pm.Categorical('z_%u' % i, p=p)
            mu = a[z]*X[i] + b[z]
            y = pm.Normal('y_%u' % i, mu=mu, sigma=2, observed=Y[i])

        print('Generating test set...')

        for i in range(N):
            z_test = pm.Categorical('z_test_%u' % i, p=p)
            mu_test = a[z_test]*X_test[i] + b[z_test]
            y_test = pm.Normal('y_test_%u' % i, mu=mu_test, sigma=2)

        trace = pm.sample(100)
        ran_traces.append(trace)

    print('Generating graph for next generation...')
    Y_test = []
    for i in range(N):
        y_pos = trace['y_test_%u'%i]
        Y_test.append(np.random.choice(y_pos))
    plt.figure()
    plt.scatter(X_test, Y_test, color="#FF00FF")
    plt.ylim([0,100])
    plt.xlim([0,100])
    plt.savefig('ran/gen_%i.jpeg'%(gen))
# Out:
# Creating model...
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# Training on 25 points...
# Generating test set...
# Only 100 samples in chain.
# INFO (theano.gof.compilelock): Refreshing lock /Users/pkarnati/.theano/compiledir_Darwin-18.7.0-x86_64-i386-64bit-i386-3.6.0-64/lock_dir/lock
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-94-f587b2306a42> in <module>()
#      47             y_test = pm.Normal('y_test_%u' % i, mu=mu_test, sigma=2)
#      48
# ---> 49         trace = pm.sample(100)
#      50         ran_traces.append(trace)
#      51
#
# ~/Library/Python/3.6/lib/python/site-packages/pymc3/sampling.py in sample(draws, step, init, n_init, start, trace, chain_idx, chains, cores, tune, progressbar, model, random_seed, discard_tuned_samples, compute_convergence_checks, **kwargs)
#     430             step = assign_step_methods(model, step, step_kwargs=kwargs)
#     431     else:
# --> 432         step = assign_step_methods(model, step, step_kwargs=kwargs)
#     433
#     434     if isinstance(step, list):
#
# ~/Library/Python/3.6/lib/python/site-packages/pymc3/sampling.py in assign_step_methods(model, step, methods, step_kwargs)
#     185             selected_steps[selected].append(var)
#     186
# --> 187     return instantiate_steppers(model, steps, selected_steps, step_kwargs)
#     188
#     189
#
# ~/Library/Python/3.6/lib/python/site-packages/pymc3/sampling.py in instantiate_steppers(model, steps, selected_steps, step_kwargs)
#     106         args = step_kwargs.get(step_class.name, {})
#     107         used_keys.add(step_class.name)
# --> 108         step = step_class(vars=vars, **args)
#     109         steps.append(step)
#     110
#
# ~/Library/Python/3.6/lib/python/site-packages/pymc3/step_methods/hmc/nuts.py in __init__(self, vars, max_treedepth, early_max_treedepth, **kwargs)
#     146         `pm.sample` to the desired number of tuning steps.
#     147         """
# --> 148         super().__init__(vars, **kwargs)
#     149
#     150         self.max_treedepth = max_treedepth
#
# ~/Library/Python/3.6/lib/python/site-packages/pymc3/step_methods/hmc/base_hmc.py in __init__(self, vars, scaling, step_scale, is_cov, model, blocked, potential, dtype, Emax, target_accept, gamma, k, t0, adapt_step_size, step_rand, **theano_kwargs)
#      70         vars = inputvars(vars)
#      71
# ---> 72         super().__init__(vars, blocked=blocked, model=model, dtype=dtype, **theano_kwargs)
#      73
#      74         self.adapt_step_size = adapt_step_size
#
# ~/Library/Python/3.6/lib/python/site-packages/pymc3/step_methods/arraystep.py in __init__(self, vars, model, blocked, dtype, **theano_kwargs)
#     226
#     227         func = model.logp_dlogp_function(
# --> 228             vars, dtype=dtype, **theano_kwargs)
#     229
#     230         # handle edge case discovered in #2948
#
# ~/Library/Python/3.6/lib/python/site-packages/pymc3/model.py in logp_dlogp_function(self, grad_vars, **kwargs)
#     817         varnames = [var.name for var in grad_vars]
#     818         extra_vars = [var for var in self.free_RVs if var.name not in varnames]
# --> 819         return ValueGradFunction(self.logpt, grad_vars, extra_vars, **kwargs)
#     820
#     821     @property
#
# ~/Library/Python/3.6/lib/python/site-packages/pymc3/model.py in __init__(self, cost, grad_vars, extra_vars, dtype, casting, **kwargs)
#     553
#     554         self._theano_function = theano.function(
# --> 555             inputs, [self._cost_joined, grad], givens=givens, **kwargs)
#     556
#     557     def set_extra_values(self, extra_vars):
#
# ~/Library/Python/3.6/lib/python/site-packages/theano/compile/function.py in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     315                    on_unused_input=on_unused_input,
#     316                    profile=profile,
# --> 317                    output_keys=output_keys)
#     318     return fn
#
# ~/Library/Python/3.6/lib/python/site-packages/theano/compile/pfunc.py in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys)
#     484                          accept_inplace=accept_inplace, name=name,
#     485                          profile=profile, on_unused_input=on_unused_input,
# --> 486                          output_keys=output_keys)
#     487
#     488
#
# ~/Library/Python/3.6/lib/python/site-packages/theano/compile/function_module.py in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys)
#    1839                   name=name)
#    1840         with theano.change_flags(compute_test_value="off"):
# -> 1841             fn = m.create(defaults)
#    1842     finally:
#    1843         t2 = time.time()
#
# ~/Library/Python/3.6/lib/python/site-packages/theano/compile/function_module.py in create(self, input_storage, trustme, storage_map)
#    1713             theano.config.traceback.limit = theano.config.traceback.compile_limit
#    1714             _fn, _i, _o = self.linker.make_thunk(
# -> 1715                 input_storage=input_storage_lists, storage_map=storage_map)
#    1716         finally:
#    1717             theano.config.traceback.limit = limit_orig
#
# ~/Library/Python/3.6/lib/python/site-packages/theano/gof/link.py in make_thunk(self, input_storage, output_storage, storage_map)
#     697         return self.make_all(input_storage=input_storage,
#     698                              output_storage=output_storage,
# --> 699                              storage_map=storage_map)[:3]
#     700
#     701     def make_all(self, input_storage, output_storage):
#
# ~/Library/Python/3.6/lib/python/site-packages/theano/gof/vm.py in make_all(self, profiler, input_storage, output_storage, storage_map)
#    1089                                                  compute_map,
#    1090                                                  [],
# -> 1091                                                  impl=impl))
#    1092                 linker_make_thunk_time[node] = time.time() - thunk_start
#    1093                 if not hasattr(thunks[-1], 'lazy'):
#
# ~/Library/Python/3.6/lib/python/site-packages/theano/gof/op.py in make_thunk(self, node, storage_map, compute_map, no_recycling, impl)
#     953             try:
#     954                 return self.make_c_thunk(node, storage_map, compute_map,
# --> 955                                          no_recycling)
#     956             except (NotImplementedError, utils.MethodNotDefined):
#     957                 # We requested the c code, so don't catch the error.
#
# ~/Library/Python/3.6/lib/python/site-packages/theano/gof/op.py in make_c_thunk(self, node, storage_map, compute_map, no_recycling)
#     856         _logger.debug('Trying CLinker.make_thunk')
#     857         outputs = cl.make_thunk(input_storage=node_input_storage,
# --> 858                                 output_storage=node_output_storage)
#     859         thunk, node_input_filters, node_output_filters = outputs
#     860
#
# ~/Library/Python/3.6/lib/python/site-packages/theano/gof/cc.py in make_thunk(self, input_storage, output_storage, storage_map, keep_lock)
#    1215         cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#    1216             input_storage, output_storage, storage_map,
# -> 1217             keep_lock=keep_lock)
#    1218
#    1219         res = _CThunk(cthunk, init_tasks, tasks, error_storage, module)
#
# ~/Library/Python/3.6/lib/python/site-packages/theano/gof/cc.py in __compile__(self, input_storage, output_storage, storage_map, keep_lock)
#    1155                                             output_storage,
#    1156                                             storage_map,
# -> 1157                                             keep_lock=keep_lock)
#    1158         return (thunk,
#    1159                 module,
#
# ~/Library/Python/3.6/lib/python/site-packages/theano/gof/cc.py in cthunk_factory(self, error_storage, in_storage, out_storage, storage_map, keep_lock)
#    1622                 node.op.prepare_node(node, storage_map, None, 'c')
#    1623             module = get_module_cache().module_from_key(
# -> 1624                 key=key, lnk=self, keep_lock=keep_lock)
#    1625
#    1626         vars = self.inputs + self.outputs + self.orphans
#
# ~/Library/Python/3.6/lib/python/site-packages/theano/gof/cmodule.py in module_from_key(self, key, lnk, keep_lock)
#    1153         # Is the source code already in the cache?
#    1154         module_hash = get_module_hash(src_code, key)
# -> 1155         module = self._get_from_hash(module_hash, key, keep_lock=keep_lock)
#    1156         if module is not None:
#    1157             return module
#
# ~/Library/Python/3.6/lib/python/site-packages/theano/gof/cmodule.py in _get_from_hash(self, module_hash, key, keep_lock)
#    1063                 if (key[0] and not key_broken and
#    1064                         self.check_for_broken_eq):
# -> 1065                     self.check_key(key, key_data.key_pkl)
#    1066             self._update_mappings(key, key_data, module.__file__, check_in_keys=not key_broken)
#    1067             return module
#
# ~/Library/Python/3.6/lib/python/site-packages/theano/gof/cmodule.py in check_key(self, key, key_pkl)
#    1234             try:
#    1235                 with open(key_pkl, 'rb') as f:
# -> 1236                     key_data = pickle.load(f)
#    1237                 break
#    1238             except EOFError:
#
# ~/Library/Python/3.6/lib/python/site-packages/theano/scalar/basic.py in __setstate__(self, d)
#    4120         return rval
#    4121
# -> 4122     def __setstate__(self, d):
#    4123         self.__dict__.update(d)
#    4124         # We must call init to set fgraph and _impls again, as otherwise
#
# KeyboardInterrupt:

# %%
xs_1, ys_1 = plot_function(0, plot=True, num_points=50)
xs = list(np.copy(xs_1))
ys = list(np.copy(ys_1))

# %%
train_x = []
train_y = []
for i in range(25):
    ind = random.randint(0, len(xs)-1)
    x = xs.pop(ind)
    y = ys.pop(ind)
    
    train_x.append(x)
    train_y.append(y)
plt.scatter(train_x, train_y)
plt.savefig('pos_gen_0.jpeg')
